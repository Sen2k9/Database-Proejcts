# %%
import urllib.request, urllib.parse, urllib.error
import http
import sqlite3
import json
import time
import ssl
import sys

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'

if api_key is False:
    api_key = 42
    serviceurl = "http://py4e-data.dr-chuck.net/json?"
else :
    serviceurl = "https://maps.googleapis.com/maps/api/geocode/json?"

# Additional detail for urllib
# http.client.HTTPConnection.debuglevel = 1

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('''
CREATE TABLE IF NOT EXISTS Locations (address TEXT, geodata TEXT)''')

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

fh = open("where.data")
count = 0
for line in fh:
    if count > 200 :
        print('Retrieved 200 locations, restart to retrieve more')
        break

    address = line.strip()
    print('')
    cur.execute("SELECT geodata FROM Locations WHERE address= ?",
        (memoryview(address.encode()), ))

    try:
        data = cur.fetchone()[0]
        print("Found in database ",address)
        continue
    except:
        pass

    parms = dict()
    parms["address"] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters', data[:20].replace('\n', ' '))
    count = count + 1

    try:
        js = json.loads(data)
    except:
        print(data)  # We print in case unicode causes an error
        continue

    if 'status' not in js or (js['status'] != 'OK' and js['status'] != 'ZERO_RESULTS') :
        print('==== Failure To Retrieve ====')
        print(data)
        break

    cur.execute('''INSERT INTO Locations (address, geodata)
            VALUES ( ?, ? )''', (memoryview(address.encode()), memoryview(data.encode()) ) )
    conn.commit()
    if count % 10 == 0 :
        print('Pausing for a bit...')
        time.sleep(5)

print("Run geodump.py to read the data from the database so you can vizualize it on a map.")
# Out:
# Retrieving http://py4e-data.dr-chuck.net/json?address=AGH+University+of+Science+and+Technology&key=42
# Retrieved 2315 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Academy+of+Fine+Arts+Warsaw+Poland&key=42
# Retrieved 1435 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=American+University+in+Cairo&key=42
# Retrieved 1613 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Arizona+State+University&key=42
# Retrieved 1802 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Athens+Information+Technology&key=42
# Retrieved 2271 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=BITS+Pilani&key=42
# Retrieved 1621 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Babcock+University&key=42
# Retrieved 3624 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Banaras+Hindu+University&key=42
# Retrieved 1989 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Bangladesh+University+of+Engineering+and+Technology&key=42
# Retrieved 2168 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Bangalore+University&key=42
# Retrieved 2241 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Baylor+University&key=42
# Retrieved 2141 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Beijing+normal+university&key=42
# Retrieved 2200 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Belarusian+State+University&key=42
# Retrieved 3686 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Belgrade+University&key=42
# Retrieved 1945 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Beloit+College&key=42
# Retrieved 2265 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Belorussian+State+University&key=42
# Retrieved 3686 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Ben+Gurion+University&key=42
# Retrieved 3228 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Bharthidasan+University&key=42
# Retrieved 1695 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Boston+University&key=42
# Retrieved 2085 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=California+Polytechnic+State+University+of+San+Luis+Obispo&key=42
# Retrieved 3974 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=California+State+University+San+Bernardino&key=42
# Retrieved 2182 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=City+of+Westminster+College&key=42
# Retrieved 2120 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Columbia+University&key=42
# Retrieved 1636 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Cranfield+University&key=42
# Retrieved 2154 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Czech+Technical+University+in+Prague&key=42
# Retrieved 2146 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Dartmouth&key=42
# Retrieved 2163 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=De+Anza+College&key=42
# Retrieved 3950 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Dhaka+University&key=42
# Retrieved 2156 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Distant+University+of+Hagen&key=42
# Retrieved 2100 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Dnipropetrovsk+National+University&key=42
# Retrieved 2442 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Dokuz+Eylul+University&key=42
# Retrieved 2157 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Drexel&key=42
# Retrieved 2351 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Drexel+University+and+University+of+Texas+at+Austin&key=42
# Retrieved 1795 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Duke+University&key=42
# Retrieved 1993 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=EM+Lyon&key=42
# Retrieved 2136 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Ecole+centrale+de+PARIS&key=42
# Retrieved 2125 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Elon+University&key=42
# Retrieved 2331 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Erhvervsakademi+Sydvest&key=42
# Retrieved 1765 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Escuela+Superior+Politecnica+del+Litoral&key=42
# Retrieved 3876 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Fachhochschule+Dusseldorf&key=42
# Retrieved 2383 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Fachhochschule+FH+Salzburg&key=42
# Retrieved 2107 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Faculdade+de+Tecnologia+do+Estado+de+Sao+Paulo&key=42
# Retrieved 2260 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Faculty+of+Technical+Sciences+Novi+Sad+Serbia&key=42
# Retrieved 2116 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Farmingdale+State+University&key=42
# Retrieved 2133 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Federal+University+of+Minas+Gerais&key=42
# Retrieved 2253 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Florida+Atlantic+University&key=42
# Retrieved 2137 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Franklin+Pierce+College&key=42
# Retrieved 2286 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Gauhati+University&key=42
# Retrieved 2026 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=George+Mason+University&key=42
# Retrieved 2314 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Georgetown+University+Law+Center&key=42
# Retrieved 2267 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Georgia+State+University&key=42
# Retrieved 1994 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Grandville&key=42
# Retrieved 1752 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Groep+T+University&key=42
# Retrieved 2084 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Hanoi+University+of+Science+and+Technology&key=42
# Retrieved 1823 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Hebrew+University&key=42
# Retrieved 1248 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=IIIT+Hyderabad&key=42
# Retrieved 2226 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=IIT+KANPUR&key=42
# Retrieved 2029 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=IT+College+of+Estonia&key=42
# Retrieved 2089 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=IU&key=42
# Retrieved 2314 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=IUAV+Venezia&key=42
# Retrieved 2306 characters {    "results" : [
# Pausing for a bit...
# Retrieving http://py4e-data.dr-chuck.net/json?address=Illinois+Institute+of+Technology&key=42
# Retrieved 2268 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Illinois+State+University+Joliet+Junior+College&key=42
# Retrieved 2467 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indian+Institute+of+Technology&key=42
# Retrieved 2268 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indian+Institute+of+Technology+Kharagpur+India&key=42
# Retrieved 1817 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indian+School+of+Mines+Dhanbad&key=42
# Retrieved 1653 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indiana+University&key=42
# Retrieved 4472 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Indiana+University+at+Bloomington&key=42
# Retrieved 2314 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Institut+Superieur+de+technologies&key=42
# Retrieved 2143 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Institute+of+Business+and+Modern+Technologies&key=42
# Retrieved 2146 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Instituto+Tecnologico+de+Santo+Domingo&key=42
# Retrieved 2209 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=International+Institute+of+Information+Technology+Hyderabad&key=42
# Retrieved 2226 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Irkutsk+State+University&key=42
# Retrieved 2146 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=JADAVPUR+UNIVERSITY&key=42
# Retrieved 2136 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Jawaharlal+Nehru+Technological+University&key=42
# Retrieved 15080 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Jawaharlal+Nehru+University&key=42
# Retrieved 1635 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Jordan+University+of+Science+and+Technology&key=42
# Retrieved 1260 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=K-State&key=42
# Retrieved 1807 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=KUL&key=42
# Retrieved 1623 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kalamazoo+College&key=42
# Retrieved 2313 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kaunas+Technology+University&key=42
# Retrieved 2130 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kaunas+university+of+technology&key=42
# Retrieved 2120 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kazan+Federal+University&key=42
# Retrieved 2350 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kent+State+University&key=42
# Retrieved 2110 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kharkiv+State+Academy+of+Municipal+Economy+Ukraine&key=42
# Retrieved 2408 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Khulna+University+of+Engineering+and+Technology&key=42
# Retrieved 2002 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=King+Mongkuts+University+of+Technology+Thonburi&key=42
# Retrieved 2247 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kokshetau+Institute+of+Economics+and+Management&key=42
# Retrieved 1960 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kyiv+Polytechnic+Institute&key=42
# Retrieved 2127 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kyiv+Polytechnical+Institute&key=42
# Retrieved 4449 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Kyiv+Unisersity+of+Oriental+Language&key=42
# Retrieved 2153 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Laurentian+University&key=42
# Retrieved 2357 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Lisandro+Alvarado&key=42
# Retrieved 52 characters {    "results" : [],
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Lodz+University+of+Technology&key=42
# Retrieved 2292 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Lviv+University&key=42
# Retrieved 2379 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=MSU&key=42
# Retrieved 2162 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Madras+university&key=42
# Retrieved 2419 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Magnitogorsk+State+Technical+University&key=42
# Retrieved 2209 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Malayer+Azad+University&key=42
# Retrieved 1663 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Marietta+College&key=42
# Retrieved 4343 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Masdar+Institute&key=42
# Retrieved 3453 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Matematicki+fakultet+Beograd&key=42
# Retrieved 2107 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Michigan+State+University&key=42
# Retrieved 2162 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Middle+East+Technical+University&key=42
# Retrieved 4486 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Missouri+University+of+Science+and+Technology&key=42
# Retrieved 2105 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monash&key=42
# Retrieved 1969 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monash+University&key=42
# Retrieved 1969 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monash+University+Churchill+Australia&key=42
# Retrieved 3906 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Monterrey+Institute+of+Technology+and+Higher+Education&key=42
# Retrieved 2187 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Moscow+Engineering-Physics+Institute&key=42
# Retrieved 2383 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Moscow+Institute+of+Physics+%26+Technology&key=42
# Retrieved 2329 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Moscow+State+University&key=42
# Retrieved 2136 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=NIT+ROURKELA&key=42
# Retrieved 2239 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=NYU&key=42
# Retrieved 2003 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Nagpur+University&key=42
# Retrieved 2162 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Nanyang+Technological+University&key=42
# Retrieved 1254 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=National+Institute+of+Technology+Jalandhar&key=42
# Retrieved 1632 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=National+Taiwan+University&key=42
# Retrieved 2017 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=National+University+of+Engineering&key=42
# Retrieved 1442 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=North+Central+College&key=42
# Retrieved 5219 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Northeastern+University&key=42
# Retrieved 2322 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Northwestern+University&key=42
# Retrieved 2130 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Obninsk+Technical+University+of+Nuclear+Power+Engineering+Russia&key=42
# Retrieved 2175 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Old+Dominion+University&key=42
# Retrieved 1932 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Oregon+Institute+of+Technology&key=42
# Retrieved 4392 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=PUCMM&key=42
# Retrieved 2029 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Payame+Noor+University&key=42
# Retrieved 1655 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Penn+State+University&key=42
# Retrieved 1843 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Politecnico+di+Milano&key=42
# Retrieved 2356 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Politehnica+University+Bucharest&key=42
# Retrieved 2365 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Polytechnic+University+of+Timisoara&key=42
# Retrieved 4231 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Pondicherry+University&key=42
# Retrieved 1611 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Pontificia+universidad+catolica+de+chile&key=42
# Retrieved 2235 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Portland+State+University&key=42
# Retrieved 2477 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Purdue+University+Indianapolis&key=42
# Retrieved 2348 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=R+V+College+of+Engineering&key=42
# Retrieved 2387 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=RPI&key=42
# Retrieved 2108 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Ramapo+College+of+New+Jersey&key=42
# Retrieved 2286 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Rochester+Institute+of+Technology&key=42
# Retrieved 2482 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=SASTRA+University&key=42
# Retrieved 1664 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Saint+Petersburg+State+University&key=42
# Retrieved 2193 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Saint+Petersburg+State+University+of+Aerospace+Instrumentation&key=42
# Retrieved 2196 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Saint-Petersburg+Polytechnic+Univesity&key=42
# Retrieved 2219 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=San+Francisco+State+University&key=42
# Retrieved 2329 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=San+Jose+State+University&key=42
# Retrieved 2324 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Shanghai+Jiao+Tong+University&key=42
# Retrieved 3381 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Sharif+University+of+Technology&key=42
# Retrieved 1114 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Simon+Bolivar+University&key=42
# Retrieved 1478 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Simon+Fraser+University&key=42
# Retrieved 2144 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Smolensk+State+University&key=42
# Retrieved 4322 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Sonoma+State+University&key=42
# Retrieved 2159 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=South+Federal+University&key=42
# Retrieved 2019 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Spiru+Haret+University&key=42
# Retrieved 2347 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Stanford&key=42
# Retrieved 1928 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=State+University+of+Campinas&key=42
# Retrieved 2118 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=State+University+of+New+York+College+at+Oswego&key=42
# Retrieved 2114 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Stellenbosch+University&key=42
# Retrieved 1903 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Stonehill+College&key=42
# Retrieved 2319 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tallinn+University&key=42
# Retrieved 2137 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tallinn+University+of+Technology&key=42
# Retrieved 2114 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tampere+University+of+Technology&key=42
# Retrieved 1733 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tanta+University&key=42
# Retrieved 1870 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tarrant+County+College&key=42
# Retrieved 2312 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Technical+University+of+Cluj-Napoca&key=42
# Retrieved 2158 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Technion&key=42
# Retrieved 1776 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tel+Aviv+University&key=42
# Retrieved 1474 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+Jerusalem+collage+of+engineering&key=42
# Retrieved 2440 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+University+of+Latvia&key=42
# Retrieved 1946 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+University+of+Manchester&key=42
# Retrieved 1978 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=The+University+of+South+Africa&key=42
# Retrieved 2163 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Transilvania+University&key=42
# Retrieved 2322 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Tufts+University&key=42
# Retrieved 1662 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UC+Berkeley&key=42
# Retrieved 1662 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UCLA&key=42
# Retrieved 2006 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UCSD&key=42
# Retrieved 2315 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UIUC&key=42
# Retrieved 1702 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UMD&key=42
# Retrieved 2469 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UNISA&key=42
# Retrieved 2462 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UNIVERSIDAD+DE+Buenos+Aires&key=42
# Retrieved 2132 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=UOC&key=42
# Retrieved 2108 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=USC&key=42
# Retrieved 2022 characters {    "results" : [
# Pausing for a bit...
# Retrieving http://py4e-data.dr-chuck.net/json?address=UW+Madison&key=42
# Retrieved 1817 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Central+de+Venezuela&key=42
# Retrieved 1678 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Complutense+de+Madrid&key=42
# Retrieved 2083 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Cooperativa+de+Colombia&key=42
# Retrieved 2139 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+Autonoma+de+Mexico&key=42
# Retrieved 2363 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+Costa+Rica&key=42
# Retrieved 1310 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Nacional+de+Colombia&key=42
# Retrieved 2137 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+Tecnologica+Boliviana&key=42
# Retrieved 2003 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Buenos+Aires&key=42
# Retrieved 2132 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Castilla+La+Mancha&key=42
# Retrieved 2164 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Los+Andes+Colombia&key=42
# Retrieved 2278 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Oriente&key=42
# Retrieved 2198 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+San+Carlos+de+Guatemala&key=42
# Retrieved 2096 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+Valladolid&key=42
# Retrieved 2118 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+de+la+Sabana&key=42
# Retrieved 1650 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidad+del+Valle+de+Guatemala&key=42
# Retrieved 2120 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+da+Paraiba&key=42
# Retrieved 1725 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+de+Santa+Catarina&key=42
# Retrieved 2318 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+do+Rio+Grande+do+Sul&key=42
# Retrieved 2230 characters {    "results" : [
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Federal+do+Rio+de+Janeiro&key=42
# Retrieved 1710 characters {    "results" : [
# Pausing for a bit...
#
# Retrieving http://py4e-data.dr-chuck.net/json?address=Universidade+Tecnica+de+Lisboa&key=42
# Retrieved 1920 characters {    "results" : [
# Retrieved 200 locations, restart to retrieve more
# Run geodump.py to read the data from the database so you can vizualize it on a map.

# %%
import sqlite3
import json
import codecs

conn = sqlite3.connect('geodata.sqlite')
cur = conn.cursor()

cur.execute('SELECT * FROM Locations')
fhand = codecs.open('where.js', 'w', "utf-8")
fhand.write("myData = [\n")
count = 0
for row in cur :
    data = str(row[1].decode())
    #print(data)
    try: js = json.loads(str(data))
    except: continue

    if not('status' in js and js['status'] == 'OK') : continue

    lat = js["results"][0]["geometry"]["location"]["lat"]
    lng = js["results"][0]["geometry"]["location"]["lng"]
    if lat == 0 or lng == 0 : continue
    where = js['results'][0]['formatted_address']
    where = where.replace("'", "")
    try :
        print(where, lat, lng)

        count = count + 1
        if count > 1 : fhand.write(",\n")
        output = "["+str(lat)+","+str(lng)+", '"+where+"']"
        fhand.write(output)
    except:
        continue

fhand.write("\n];\n")
cur.close()
fhand.close()
print(count, "records written to where.js")
print("Open where.html to view the data in a browser")
# Out:
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "30",
#                "short_name" : "30",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "aleja Adama Mickiewicza",
#                "short_name" : "aleja Adama Mickiewicza",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Krowodrza",
#                "short_name" : "Krowodrza",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Kraków",
#                "short_name" : "Kraków",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Kraków",
#                "short_name" : "Kraków",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "małopolskie",
#                "short_name" : "małopolskie",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Poland",
#                "short_name" : "PL",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "30-059",
#                "short_name" : "30-059",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "aleja Adama Mickiewicza 30, 30-059 Kraków, Poland",
#          "geometry" : {
#             "location" : {
#                "lat" : 50.06688579999999,
#                "lng" : 19.9136192
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 50.0682347802915,
#                   "lng" : 19.9149681802915
#                },
#                "southwest" : {
#                   "lat" : 50.0655368197085,
#                   "lng" : 19.9122702197085
#                }
#             }
#          },
#          "place_id" : "ChIJIZu1VqdbFkcR0RezIbqNDLI",
#          "plus_code" : {
#             "compound_code" : "3W87+QC Kraków, Poland",
#             "global_code" : "9F2X3W87+QC"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# aleja Adama Mickiewicza 30, 30-059 Kraków, Poland 50.06688579999999 19.9136192
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Warszawa",
#                "short_name" : "Warszawa",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Poland",
#                "short_name" : "PL",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "00-068",
#                "short_name" : "00-068",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Krakowskie Przedmieście 5, 00-068 Warszawa, Poland",
#          "geometry" : {
#             "location" : {
#                "lat" : 52.2394019,
#                "lng" : 21.0150792
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 52.2407508802915,
#                   "lng" : 21.0164281802915
#                },
#                "southwest" : {
#                   "lat" : 52.2380529197085,
#                   "lng" : 21.0137302197085
#                }
#             }
#          },
#          "place_id" : "ChIJLzAMf2DMHkcR5qCqT76Dq9M",
#          "plus_code" : {
#             "compound_code" : "62Q8+Q2 Warsaw, Poland",
#             "global_code" : "9G4362Q8+Q2"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Krakowskie Przedmieście 5, 00-068 Warszawa, Poland 52.2394019 21.0150792
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "AUC Avenue",
#                "short_name" : "AUC Ave",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Cairo Governorate",
#                "short_name" : "Cairo Governorate",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Egypt",
#                "short_name" : "EG",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "11835",
#                "short_name" : "11835",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "AUC Ave, Cairo Governorate 11835, Egypt",
#          "geometry" : {
#             "location" : {
#                "lat" : 30.018923,
#                "lng" : 31.499674
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 30.0202719802915,
#                   "lng" : 31.5010229802915
#                },
#                "southwest" : {
#                   "lat" : 30.0175740197085,
#                   "lng" : 31.4983250197085
#                }
#             }
#          },
#          "place_id" : "ChIJ0Rb5-FoiWBQRxwXiQTG_6HU",
#          "plus_code" : {
#             "compound_code" : "2F9X+HV New Cairo City, Egypt",
#             "global_code" : "8G2H2F9X+HV"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# AUC Ave, Cairo Governorate 11835, Egypt 30.018923 31.499674
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Tempe",
#                "short_name" : "Tempe",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Maricopa County",
#                "short_name" : "Maricopa County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Arizona",
#                "short_name" : "AZ",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "85281",
#                "short_name" : "85281",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Tempe, AZ 85281, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 33.4242399,
#                "lng" : -111.9280527
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 33.42558888029149,
#                   "lng" : -111.9267037197085
#                },
#                "southwest" : {
#                   "lat" : 33.42289091970849,
#                   "lng" : -111.9294016802915
#                }
#             }
#          },
#          "place_id" : "ChIJD1QzO9sIK4cRMzA8R39xbmY",
#          "plus_code" : {
#             "compound_code" : "C3FC+MQ Tempe, Arizona, United States",
#             "global_code" : "855CC3FC+MQ"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Tempe, AZ 85281, USA 33.4242399 -111.9280527
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "300",
#                "short_name" : "300",
#                "types" : [ "premise" ]
#             },
#             {
#                "long_name" : "2500",
#                "short_name" : "2500",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Daniells Bridge Road",
#                "short_name" : "Daniells Bridge Rd",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Athens",
#                "short_name" : "Athens",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Oconee County",
#                "short_name" : "Oconee County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Georgia",
#                "short_name" : "GA",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "30606",
#                "short_name" : "30606",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "300, 2500 Daniells Bridge Rd, Athens, GA 30606, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 33.9094132,
#                "lng" : -83.4603953
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 33.9107621802915,
#                   "lng" : -83.45904631970849
#                },
#                "southwest" : {
#                   "lat" : 33.9080642197085,
#                   "lng" : -83.46174428029151
#                }
#             }
#          },
#          "place_id" : "ChIJX-nQnzZy9ogRR_2GUv9bDM0",
#          "plus_code" : {
#             "compound_code" : "WG5Q+QR Barber Creek Estates",
#             "global_code" : "865RWG5Q+QR"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# 300, 2500 Daniells Bridge Rd, Athens, GA 30606, USA 33.9094132 -83.4603953
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Pilani",
#                "short_name" : "Pilani",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Rajasthan",
#                "short_name" : "RJ",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "India",
#                "short_name" : "IN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "333031",
#                "short_name" : "333031",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Vidya Vihar, Pilani, Rajasthan 333031, India",
#          "geometry" : {
#             "location" : {
#                "lat" : 28.3588163,
#                "lng" : 75.58802039999999
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 28.3601652802915,
#                   "lng" : 75.5893693802915
#                },
#                "southwest" : {
#                   "lat" : 28.3574673197085,
#                   "lng" : 75.58667141970848
#                }
#             }
#          },
#          "place_id" : "ChIJdUU-9GQZEzkRTYjPVAjTuh8",
#          "plus_code" : {
#             "compound_code" : "9H5Q+G6 Pilani, Rajasthan, India",
#             "global_code" : "7JWQ9H5Q+G6"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Vidya Vihar, Pilani, Rajasthan 333031, India 28.3588163 75.58802039999999
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Ilishan-Remo",
#                "short_name" : "Ilishan-Remo",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Ikenne",
#                "short_name" : "Ikenne",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Ogun State",
#                "short_name" : "OG",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Nigeria",
#                "short_name" : "NG",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Ilishan-Remo, Nigeria",
#          "geometry" : {
#             "location" : {
#                "lat" : 6.8939569,
#                "lng" : 3.7187158
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 6.895305880291502,
#                   "lng" : 3.720064780291503
#                },
#                "southwest" : {
#                   "lat" : 6.892607919708498,
#                   "lng" : 3.717366819708498
#                }
#             }
#          },
#          "place_id" : "ChIJw07lORbYOxARUn42yKi0KZE",
#          "plus_code" : {
#             "compound_code" : "VPV9+HF Ilishan-Remo, Nigeria",
#             "global_code" : "6FR5VPV9+HF"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       },
#       {
#          "address_components" : [
#             {
#                "long_name" : "Babcock University ICT Unit",
#                "short_name" : "Babcock University ICT Unit",
#                "types" : [ "premise" ]
#             },
#             {
#                "long_name" : "Joseph Vavrineck Road",
#                "short_name" : "Joseph Vavrineck Rd",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Ilishan-Remo",
#                "short_name" : "Ilishan-Remo",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Ikenne",
#                "short_name" : "Ikenne",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Ogun State",
#                "short_name" : "OG",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Nigeria",
#                "short_name" : "NG",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Babcock University ICT Unit, Joseph Vavrineck Rd, Ilishan-Remo, Nigeria",
#          "geometry" : {
#             "location" : {
#                "lat" : 6.8862448,
#                "lng" : 3.7055016
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 6.887593780291502,
#                   "lng" : 3.706850580291503
#                },
#                "southwest" : {
#                   "lat" : 6.884895819708498,
#                   "lng" : 3.704152619708498
#                }
#             }
#          },
#          "place_id" : "ChIJe8cVnjXYOxARbNn_kinXrnU",
#          "plus_code" : {
#             "compound_code" : "VPP4+F6 Ilishan-Remo, Nigeria",
#             "global_code" : "6FR5VPP4+F6"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Ilishan-Remo, Nigeria 6.8939569 3.7187158
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Ajagara",
#                "short_name" : "Ajagara",
#                "types" : [ "neighborhood", "political" ]
#             },
#             {
#                "long_name" : "Varanasi",
#                "short_name" : "Varanasi",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Varanasi",
#                "short_name" : "Varanasi",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Uttar Pradesh",
#                "short_name" : "UP",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "India",
#                "short_name" : "IN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "221005",
#                "short_name" : "221005",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Ajagara, Varanasi, Uttar Pradesh 221005, India",
#          "geometry" : {
#             "location" : {
#                "lat" : 25.2677203,
#                "lng" : 82.99125819999999
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 25.2690692802915,
#                   "lng" : 82.99260718029149
#                },
#                "southwest" : {
#                   "lat" : 25.2663713197085,
#                   "lng" : 82.98990921970848
#                }
#             }
#          },
#          "place_id" : "ChIJVx24kCkyjjkRJ4c60-w9fBg",
#          "plus_code" : {
#             "compound_code" : "7X9R+3G Varanasi, Uttar Pradesh, India",
#             "global_code" : "7MQ47X9R+3G"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Ajagara, Varanasi, Uttar Pradesh 221005, India 25.2677203 82.99125819999999
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "BUET Central Road",
#                "short_name" : "BUET Central Road",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Ramna",
#                "short_name" : "Ramna",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Dhaka",
#                "short_name" : "Dhaka",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Dhaka District",
#                "short_name" : "Dhaka District",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Dhaka Division",
#                "short_name" : "Dhaka Division",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Bangladesh",
#                "short_name" : "BD",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "1000",
#                "short_name" : "1000",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "BUET Central Road, Dhaka 1000, Bangladesh",
#          "geometry" : {
#             "location" : {
#                "lat" : 23.7261021,
#                "lng" : 90.3919298
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 23.7274510802915,
#                   "lng" : 90.39327878029151
#                },
#                "southwest" : {
#                   "lat" : 23.7247531197085,
#                   "lng" : 90.3905808197085
#                }
#             }
#          },
#          "place_id" : "ChIJtYTvx8K4VTcRzNSZYE1JDBQ",
#          "plus_code" : {
#             "compound_code" : "P9GR+CQ Dhaka, Bangladesh",
#             "global_code" : "7MMGP9GR+CQ"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# BUET Central Road, Dhaka 1000, Bangladesh 23.7261021 90.3919298
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Gnana Bharathi Main Road",
#                "short_name" : "Gnana Bharathi Main Rd",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Gnana Bharathi",
#                "short_name" : "Gnana Bharathi",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Bengaluru",
#                "short_name" : "Bengaluru",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Bangalore Urban",
#                "short_name" : "Bangalore Urban",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Karnataka",
#                "short_name" : "KA",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "India",
#                "short_name" : "IN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "560056",
#                "short_name" : "560056",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Gnana Bharathi Main Rd, Gnana Bharathi, Bengaluru, Karnataka 560056, India",
#          "geometry" : {
#             "location" : {
#                "lat" : 12.9504371,
#                "lng" : 77.50220849999999
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 12.9517860802915,
#                   "lng" : 77.50355748029151
#                },
#                "southwest" : {
#                   "lat" : 12.9490881197085,
#                   "lng" : 77.50085951970848
#                }
#             }
#          },
#          "place_id" : "ChIJc64iWn0-rjsRqZlBnbHY75k",
#          "plus_code" : {
#             "compound_code" : "XG22+5V Bengaluru, Karnataka, India",
#             "global_code" : "7J4VXG22+5V"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Gnana Bharathi Main Rd, Gnana Bharathi, Bengaluru, Karnataka 560056, India 12.9504371 77.5022085
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "1301",
#                "short_name" : "1301",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "South University Parks Drive",
#                "short_name" : "S University Parks Dr",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Waco",
#                "short_name" : "Waco",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "McLennan County",
#                "short_name" : "McLennan County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Texas",
#                "short_name" : "TX",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "76706",
#                "short_name" : "76706",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "1301 S University Parks Dr, Waco, TX 76706, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 31.5497007,
#                "lng" : -97.1143046
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 31.5510496802915,
#                   "lng" : -97.11295561970849
#                },
#                "southwest" : {
#                   "lat" : 31.5483517197085,
#                   "lng" : -97.11565358029151
#                }
#             }
#          },
#          "place_id" : "ChIJkebHSWqCT4YR3df3-lbTamM",
#          "plus_code" : {
#             "compound_code" : "GVXP+V7 Waco, Texas, United States",
#             "global_code" : "8634GVXP+V7"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# 1301 S University Parks Dr, Waco, TX 76706, USA 31.5497007 -97.1143046
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "19",
#                "short_name" : "19",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Xinjiekou Outer Street",
#                "short_name" : "Xinjiekou Outer St",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Bei Tai Ping Zhuang",
#                "short_name" : "Bei Tai Ping Zhuang",
#                "types" : [ "neighborhood", "political" ]
#             },
#             {
#                "long_name" : "Haidian Qu",
#                "short_name" : "Haidian Qu",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Beijing Shi",
#                "short_name" : "Beijing Shi",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "China",
#                "short_name" : "CN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "100875",
#                "short_name" : "100875",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "19 Xinjiekou Outer St, Bei Tai Ping Zhuang, Haidian Qu, Beijing Shi, China, 100875",
#          "geometry" : {
#             "location" : {
#                "lat" : 39.9619537,
#                "lng" : 116.3662615
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 39.96330268029149,
#                   "lng" : 116.3676104802915
#                },
#                "southwest" : {
#                   "lat" : 39.96060471970849,
#                   "lng" : 116.3649125197085
#                }
#             }
#          },
#          "place_id" : "ChIJxfN4FJpT8DURc9euvSu2ob0",
#          "plus_code" : {
#             "compound_code" : "X968+QG Haidian, Beijing, China",
#             "global_code" : "8PFRX968+QG"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# 19 Xinjiekou Outer St, Bei Tai Ping Zhuang, Haidian Qu, Beijing Shi, China, 100875 39.9619537 116.3662615
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "4",
#                "short_name" : "4",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Prospekt Nezavisimosti",
#                "short_name" : "Prospekt Nezavisimosti",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Maskoŭski rajon",
#                "short_name" : "Maskoŭski rajon",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Minsk",
#                "short_name" : "Minsk",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Belarus",
#                "short_name" : "BY",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Prospekt Nezavisimosti 4, Minsk, Belarus",
#          "geometry" : {
#             "location" : {
#                "lat" : 53.8938988,
#                "lng" : 27.5460609
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 53.89524778029149,
#                   "lng" : 27.5474098802915
#                },
#                "southwest" : {
#                   "lat" : 53.8925498197085,
#                   "lng" : 27.5447119197085
#                }
#             }
#          },
#          "place_id" : "ChIJVUqIm-fP20YRj5roNMigAqg",
#          "plus_code" : {
#             "compound_code" : "VGVW+HC Minsk, Belarus",
#             "global_code" : "9G59VGVW+HC"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       },
#       {
#          "address_components" : [
#             {
#                "long_name" : "17",
#                "short_name" : "17",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "vulica Rabkoraŭskaja",
#                "short_name" : "vulica Rabkoraŭskaja",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Kastryčnicki rajon",
#                "short_name" : "Kastryčnicki rajon",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Minsk",
#                "short_name" : "Minsk",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Belarus",
#                "short_name" : "BY",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "220007",
#                "short_name" : "220007",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "vulica Rabkoraŭskaja 17, Minsk 220007, Belarus",
#          "geometry" : {
#             "location" : {
#                "lat" : 53.886864,
#                "lng" : 27.5418905
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 53.8882129802915,
#                   "lng" : 27.5432394802915
#                },
#                "southwest" : {
#                   "lat" : 53.8855150197085,
#                   "lng" : 27.5405415197085
#                }
#             }
#          },
#          "place_id" : "ChIJs4tH49_P20YRMW0pE5A376M",
#          "plus_code" : {
#             "compound_code" : "VGPR+PQ Minsk, Belarus",
#             "global_code" : "9G59VGPR+PQ"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Prospekt Nezavisimosti 4, Minsk, Belarus 53.8938988 27.5460609
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "1",
#                "short_name" : "1",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Studentski trg",
#                "short_name" : "Studentski trg",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Stari Grad",
#                "short_name" : "Stari Grad",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Beograd",
#                "short_name" : "BG",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Grad Beograd",
#                "short_name" : "Grad Beograd",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Serbia",
#                "short_name" : "RS",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Studentski trg 1, Beograd, Serbia",
#          "geometry" : {
#             "location" : {
#                "lat" : 44.8184339,
#                "lng" : 20.4575676
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 44.8197828802915,
#                   "lng" : 20.4589165802915
#                },
#                "southwest" : {
#                   "lat" : 44.8170849197085,
#                   "lng" : 20.45621861970849
#                }
#             }
#          },
#          "place_id" : "ChIJv_ehNbN6WkcROV6HX6xX5Vc",
#          "plus_code" : {
#             "compound_code" : "RF95+92 Belgrade, Serbia",
#             "global_code" : "8GP2RF95+92"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Studentski trg 1, Beograd, Serbia 44.8184339 20.4575676
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "700",
#                "short_name" : "700",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "College Street",
#                "short_name" : "College St",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Beloit",
#                "short_name" : "Beloit",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Rock County",
#                "short_name" : "Rock County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Wisconsin",
#                "short_name" : "WI",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "53511",
#                "short_name" : "53511",
#                "types" : [ "postal_code" ]
#             },
#             {
#                "long_name" : "5509",
#                "short_name" : "5509",
#                "types" : [ "postal_code_suffix" ]
#             }
#          ],
#          "formatted_address" : "700 College St, Beloit, WI 53511, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 42.5030333,
#                "lng" : -89.0309048
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 42.50438228029149,
#                   "lng" : -89.02955581970851
#                },
#                "southwest" : {
#                   "lat" : 42.5016843197085,
#                   "lng" : -89.03225378029151
#                }
#             }
#          },
#          "place_id" : "ChIJBchm5CahCIgRLbbEDEzoELY",
#          "plus_code" : {
#             "compound_code" : "GX39+6J Beloit, Wisconsin, United States",
#             "global_code" : "86JGGX39+6J"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# 700 College St, Beloit, WI 53511, USA 42.5030333 -89.0309048
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "4",
#                "short_name" : "4",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Prospekt Nezavisimosti",
#                "short_name" : "Prospekt Nezavisimosti",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Maskoŭski rajon",
#                "short_name" : "Maskoŭski rajon",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Minsk",
#                "short_name" : "Minsk",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Belarus",
#                "short_name" : "BY",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Prospekt Nezavisimosti 4, Minsk, Belarus",
#          "geometry" : {
#             "location" : {
#                "lat" : 53.8938988,
#                "lng" : 27.5460609
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 53.89524778029149,
#                   "lng" : 27.5474098802915
#                },
#                "southwest" : {
#                   "lat" : 53.8925498197085,
#                   "lng" : 27.5447119197085
#                }
#             }
#          },
#          "place_id" : "ChIJVUqIm-fP20YRj5roNMigAqg",
#          "plus_code" : {
#             "compound_code" : "VGVW+HC Minsk, Belarus",
#             "global_code" : "9G59VGVW+HC"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       },
#       {
#          "address_components" : [
#             {
#                "long_name" : "17",
#                "short_name" : "17",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "vulica Rabkoraŭskaja",
#                "short_name" : "vulica Rabkoraŭskaja",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Kastryčnicki rajon",
#                "short_name" : "Kastryčnicki rajon",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Minsk",
#                "short_name" : "Minsk",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Belarus",
#                "short_name" : "BY",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "220007",
#                "short_name" : "220007",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "vulica Rabkoraŭskaja 17, Minsk 220007, Belarus",
#          "geometry" : {
#             "location" : {
#                "lat" : 53.886864,
#                "lng" : 27.5418905
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 53.8882129802915,
#                   "lng" : 27.5432394802915
#                },
#                "southwest" : {
#                   "lat" : 53.8855150197085,
#                   "lng" : 27.5405415197085
#                }
#             }
#          },
#          "place_id" : "ChIJs4tH49_P20YRMW0pE5A376M",
#          "plus_code" : {
#             "compound_code" : "VGPR+PQ Minsk, Belarus",
#             "global_code" : "9G59VGPR+PQ"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Prospekt Nezavisimosti 4, Minsk, Belarus 53.8938988 27.5460609
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "1",
#                "short_name" : "1",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "שד' בן-גוריון",
#                "short_name" : "שד' בן-גוריון",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "באר שבע",
#                "short_name" : "ב\"ש",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "באר שבע",
#                "short_name" : "באר שבע",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "מחוז הדרום",
#                "short_name" : "מחוז הדרום",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Israel",
#                "short_name" : "IL",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "שד' בן-גוריון 1, באר שבע, Israel",
#          "geometry" : {
#             "location" : {
#                "lat" : 31.262218,
#                "lng" : 34.801461
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 31.2635669802915,
#                   "lng" : 34.8028099802915
#                },
#                "southwest" : {
#                   "lat" : 31.2608690197085,
#                   "lng" : 34.8001120197085
#                }
#             }
#          },
#          "place_id" : "ChIJG8cBLl9mAhURk7hAwbBNyhU",
#          "plus_code" : {
#             "compound_code" : "7R62+VH Be'er Sheva, Israel",
#             "global_code" : "8G3P7R62+VH"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       },
#       {
#          "address_components" : [
#             {
#                "long_name" : "8410501",
#                "short_name" : "8410501",
#                "types" : [ "postal_code" ]
#             },
#             {
#                "long_name" : "Israel",
#                "short_name" : "IL",
#                "types" : [ "country", "political" ]
#             }
#          ],
#          "formatted_address" : "Caroline House, Faculty of Health Sciences, Ben-Gurion University of the Negev Be'er Sheva, 8410501, Israel",
#          "geometry" : {
#             "location" : {
#                "lat" : 31.2521017,
#                "lng" : 34.7951527
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 31.2534506802915,
#                   "lng" : 34.79650168029151
#                },
#                "southwest" : {
#                   "lat" : 31.2507527197085,
#                   "lng" : 34.79380371970851
#                }
#             }
#          },
#          "place_id" : "ChIJOX5Ki49nAhURsMK972Ougzo",
#          "plus_code" : {
#             "compound_code" : "7Q2W+R3 Be'er Sheva, Israel",
#             "global_code" : "8G3P7Q2W+R3"
#          },
#          "types" : [ "establishment", "health", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# שד בן-גוריון 1, באר שבע, Israel 31.262218 34.801461
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Tiruchirappalli",
#                "short_name" : "Tiruchirappalli",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Tamil Nadu",
#                "short_name" : "TN",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "India",
#                "short_name" : "IN",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "620024",
#                "short_name" : "620024",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Palkalaiperur, Tiruchirappalli, Tamil Nadu 620024, India",
#          "geometry" : {
#             "location" : {
#                "lat" : 10.6779085,
#                "lng" : 78.74454879999999
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 10.6792574802915,
#                   "lng" : 78.7458977802915
#                },
#                "southwest" : {
#                   "lat" : 10.6765595197085,
#                   "lng" : 78.74319981970848
#                }
#             }
#          },
#          "partial_match" : true,
#          "place_id" : "ChIJP1IUwk2JqjsRc3y97ndv37A",
#          "plus_code" : {
#             "compound_code" : "MPHV+5R Tiruchirappalli, Tamil Nadu, India",
#             "global_code" : "7J2WMPHV+5R"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Palkalaiperur, Tiruchirappalli, Tamil Nadu 620024, India 10.6779085 78.74454879999999
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Boston",
#                "short_name" : "Boston",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Fenway–Kenmore",
#                "short_name" : "Fenway–Kenmore",
#                "types" : [ "neighborhood", "political" ]
#             },
#             {
#                "long_name" : "Suffolk County",
#                "short_name" : "Suffolk County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Massachusetts",
#                "short_name" : "MA",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "02215",
#                "short_name" : "02215",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Boston, MA 02215, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 42.3504997,
#                "lng" : -71.1053991
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 42.3518486802915,
#                   "lng" : -71.1040501197085
#                },
#                "southwest" : {
#                   "lat" : 42.3491507197085,
#                   "lng" : -71.10674808029151
#                }
#             }
#          },
#          "place_id" : "ChIJFzjlY_B544kRyL6j4ABuNCs",
#          "plus_code" : {
#             "compound_code" : "9V2V+5R Boston, Massachusetts, United States",
#             "global_code" : "87JC9V2V+5R"
#          },
#          "types" : [
#             "establishment",
#             "health",
#             "point_of_interest",
#             "political",
#             "university"
#          ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Boston, MA 02215, USA 42.3504997 -71.1053991
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "San Luis Obispo",
#                "short_name" : "San Luis Obispo",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "San Luis Obispo County",
#                "short_name" : "San Luis Obispo County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "California",
#                "short_name" : "CA",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "United States",
#                "short_name" : "US",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "93407",
#                "short_name" : "93407",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "San Luis Obispo, CA 93407, USA",
#          "geometry" : {
#             "location" : {
#                "lat" : 35.3050053,
#                "lng" : -120.6624942
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 35.3063542802915,
#                   "lng" : -120.6611452197085
#                },
#                "southwest" : {
#                   "lat" : 35.3036563197085,
#                   "lng" : -120.6638431802915
#                }
#             }
#          },
#          "place_id" : "ChIJUTVMBbTx7IARA5HZKYq0s5g",
#          "plus_code" : {
#             "compound_code" : "884Q+22 San Luis Obispo, California, United States",
#             "global_code" : "847X884Q+22"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       },
#       {
#          "address_components" : [
#             {
#                "long_name" : "1",
#                "short_name" : "1",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Grand Avenue",
#                "short_name" : "Grand Ave",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "San Luis Obispo",
#                "short_name" : "San Luis Obispo",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "San Luis Obispo County",
#                "short_name" : "San Luis Obispo County",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "California",
#                "short_name" : "CA",
# ...
#                "long_name" : "Valladolid",
#                "short_name" : "VA",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Castilla y León",
#                "short_name" : "CL",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Spain",
#                "short_name" : "ES",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "47002",
#                "short_name" : "47002",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "C/Plaza de Santa Cruz, 8, 47002 Valladolid, Spain",
#          "geometry" : {
#             "location" : {
#                "lat" : 41.6569271,
#                "lng" : -4.7140547
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 41.65827608029151,
#                   "lng" : -4.712705719708498
#                },
#                "southwest" : {
#                   "lat" : 41.65557811970851,
#                   "lng" : -4.715403680291502
#                }
#             }
#          },
#          "place_id" : "ChIJQ3voe68SRw0RMsmQOvIw8cg",
#          "plus_code" : {
#             "compound_code" : "M74P+Q9 Valladolid, Spain",
#             "global_code" : "8CHQM74P+Q9"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# C/Plaza de Santa Cruz, 8, 47002 Valladolid, Spain 41.6569271 -4.7140547
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Colombia",
#                "short_name" : "CO",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "Chía",
#                "short_name" : "Chía",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Cundinamarca",
#                "short_name" : "Cundinamarca",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "250001",
#                "short_name" : "250001",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Chía, Cundinamarca, Colombia",
#          "geometry" : {
#             "location" : {
#                "lat" : 4.8615787,
#                "lng" : -74.0325368
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 4.862927680291502,
#                   "lng" : -74.03118781970849
#                },
#                "southwest" : {
#                   "lat" : 4.860229719708498,
#                   "lng" : -74.0338857802915
#                }
#             }
#          },
#          "place_id" : "ChIJ0dzQiP6HP44RpPAK-KBoDlk",
#          "plus_code" : {
#             "compound_code" : "VX68+JX Chía, Cundinamarca, Colombia",
#             "global_code" : "67P7VX68+JX"
#          },
#          "types" : [ "establishment", "point_of_interest", "political", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Chía, Cundinamarca, Colombia 4.8615787 -74.0325368
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "11-95",
#                "short_name" : "11-95",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "18 Avenida",
#                "short_name" : "18 Avenida",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Zona 15",
#                "short_name" : "Zona 15",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Guatemala",
#                "short_name" : "Guate",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Guatemala",
#                "short_name" : "Guatemala",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Guatemala",
#                "short_name" : "GT",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "01015",
#                "short_name" : "01015",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "18 Avenida 11-95, Guatemala 01015, Guatemala",
#          "geometry" : {
#             "location" : {
#                "lat" : 14.603762,
#                "lng" : -90.48924799999999
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 14.6051109802915,
#                   "lng" : -90.48789901970848
#                },
#                "southwest" : {
#                   "lat" : 14.6024130197085,
#                   "lng" : -90.49059698029149
#                }
#             }
#          },
#          "place_id" : "ChIJb19HkamjiYUR8HVUR-FC7T0",
#          "plus_code" : {
#             "compound_code" : "JG36+G8 Guatemala City, Guatemala",
#             "global_code" : "766FJG36+G8"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# 18 Avenida 11-95, Guatemala 01015, Guatemala 14.603762 -90.48924799999999
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Loteamento Cidade Universitaria",
#                "short_name" : "Lot. Cidade Universitaria",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Paraíba",
#                "short_name" : "PB",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Brazil",
#                "short_name" : "BR",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "58051-900",
#                "short_name" : "58051-900",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Campus I - Lot. Cidade Universitaria, PB, 58051-900, Brazil",
#          "geometry" : {
#             "location" : {
#                "lat" : -7.1373701,
#                "lng" : -34.8455514
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : -7.136021119708498,
#                   "lng" : -34.84420241970849
#                },
#                "southwest" : {
#                   "lat" : -7.138719080291502,
#                   "lng" : -34.84690038029149
#                }
#             }
#          },
#          "place_id" : "ChIJ0QSqrrfCrAcRH2pOIcNSg_c",
#          "plus_code" : {
#             "compound_code" : "V573+3Q João Pessoa, State of Paraíba, Brazil",
#             "global_code" : "6947V573+3Q"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Campus I - Lot. Cidade Universitaria, PB, 58051-900, Brazil -7.1373701 -34.8455514
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "s/n",
#                "short_name" : "s/n",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Rua Engenheiro Agronômico Andrei Cristian Ferreira",
#                "short_name" : "R. Eng. Agronômico Andrei Cristian Ferreira",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Trindade",
#                "short_name" : "Trindade",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Florianópolis",
#                "short_name" : "Florianópolis",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Santa Catarina",
#                "short_name" : "SC",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Brazil",
#                "short_name" : "BR",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "88040-900",
#                "short_name" : "88040-900",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "R. Eng. Agronômico Andrei Cristian Ferreira, s/n - Trindade, Florianópolis - SC, 88040-900, Brazil",
#          "geometry" : {
#             "location" : {
#                "lat" : -27.6007034,
#                "lng" : -48.5191775
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : -27.5993544197085,
#                   "lng" : -48.51782851970851
#                },
#                "southwest" : {
#                   "lat" : -27.6020523802915,
#                   "lng" : -48.52052648029151
#                }
#             }
#          },
#          "place_id" : "ChIJp7yoBqs5J5URnQ9eOKG8BJk",
#          "plus_code" : {
#             "compound_code" : "9FXJ+P8 Trindade - Destero, Florianópolis - State of Santa Catarina, Brazil",
#             "global_code" : "584H9FXJ+P8"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# R. Eng. Agronômico Andrei Cristian Ferreira, s/n - Trindade, Florianópolis - SC, 88040-900, Brazil -27.6007034 -48.5191775
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "110",
#                "short_name" : "110",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Avenida Paulo Gama",
#                "short_name" : "Av. Paulo Gama",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Farroupilha",
#                "short_name" : "Farroupilha",
#                "types" : [ "political", "sublocality", "sublocality_level_1" ]
#             },
#             {
#                "long_name" : "Porto Alegre",
#                "short_name" : "Porto Alegre",
#                "types" : [ "administrative_area_level_2", "political" ]
#             },
#             {
#                "long_name" : "Rio Grande do Sul",
#                "short_name" : "RS",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Brazil",
#                "short_name" : "BR",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "90040-060",
#                "short_name" : "90040-060",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Av. Paulo Gama, 110 - Farroupilha, Porto Alegre - RS, 90040-060, Brazil",
#          "geometry" : {
#             "location" : {
#                "lat" : -30.0335969,
#                "lng" : -51.2198396
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : -30.0322479197085,
#                   "lng" : -51.2184906197085
#                },
#                "southwest" : {
#                   "lat" : -30.0349458802915,
#                   "lng" : -51.2211885802915
#                }
#             }
#          },
#          "place_id" : "ChIJM-_QAU94GZURtsdLFs3QN0Y",
#          "plus_code" : {
#             "compound_code" : "XQ8J+H3 Farroupilha, Porto Alegre - State of Rio Grande do Sul, Brazil",
#             "global_code" : "48XCXQ8J+H3"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Av. Paulo Gama, 110 - Farroupilha, Porto Alegre - RS, 90040-060, Brazil -30.0335969 -51.2198396
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "Rio de Janeiro",
#                "short_name" : "Rio de Janeiro",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Rio de Janeiro",
#                "short_name" : "RJ",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Brazil",
#                "short_name" : "BR",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "21941-901",
#                "short_name" : "21941-901",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Av. Pedro Calmon, 550 - Cidade Universitária, Rio de Janeiro - RJ, 21941-901, Brazil",
#          "geometry" : {
#             "location" : {
#                "lat" : -22.9541412,
#                "lng" : -43.1753638
#             },
#             "location_type" : "GEOMETRIC_CENTER",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : -22.9527922197085,
#                   "lng" : -43.1740148197085
#                },
#                "southwest" : {
#                   "lat" : -22.9554901802915,
#                   "lng" : -43.1767127802915
#                }
#             }
#          },
#          "place_id" : "ChIJ8RL8tfd_mQARkmERWLUKQUI",
#          "plus_code" : {
#             "compound_code" : "2RWF+8V Rio de Janeiro, State of Rio de Janeiro, Brazil",
#             "global_code" : "589R2RWF+8V"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Av. Pedro Calmon, 550 - Cidade Universitária, Rio de Janeiro - RJ, 21941-901, Brazil -22.9541412 -43.1753638
# {
#    "results" : [
#       {
#          "address_components" : [
#             {
#                "long_name" : "1",
#                "short_name" : "1",
#                "types" : [ "street_number" ]
#             },
#             {
#                "long_name" : "Avenida Rovisco Pais",
#                "short_name" : "Av. Rovisco Pais",
#                "types" : [ "route" ]
#             },
#             {
#                "long_name" : "Lisboa",
#                "short_name" : "Lisboa",
#                "types" : [ "locality", "political" ]
#             },
#             {
#                "long_name" : "Lisboa",
#                "short_name" : "Lisboa",
#                "types" : [ "administrative_area_level_1", "political" ]
#             },
#             {
#                "long_name" : "Portugal",
#                "short_name" : "PT",
#                "types" : [ "country", "political" ]
#             },
#             {
#                "long_name" : "1049-001",
#                "short_name" : "1049-001",
#                "types" : [ "postal_code" ]
#             }
#          ],
#          "formatted_address" : "Av. Rovisco Pais 1, 1049-001 Lisboa, Portugal",
#          "geometry" : {
#             "location" : {
#                "lat" : 38.7368192,
#                "lng" : -9.138705
#             },
#             "location_type" : "ROOFTOP",
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 38.7381681802915,
#                   "lng" : -9.137356019708497
#                },
#                "southwest" : {
#                   "lat" : 38.7354702197085,
#                   "lng" : -9.140053980291501
#                }
#             }
#          },
#          "place_id" : "ChIJFx-oSqIzGQ0RI0SlMcfHgAg",
#          "plus_code" : {
#             "compound_code" : "PVP6+PG Lisbon, Portugal",
#             "global_code" : "8CCGPVP6+PG"
#          },
#          "types" : [ "establishment", "point_of_interest", "university" ]
#       }
#    ],
#    "status" : "OK"
# }
#
# Av. Rovisco Pais 1, 1049-001 Lisboa, Portugal 38.7368192 -9.138705
# 200 records written to where.js
# Open where.html to view the data in a browser
